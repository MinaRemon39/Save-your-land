# %% [markdown]
# # **Installing Libraries & Data**

# %%
! pip install ultralytics
! pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 32.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 96.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Key_of_roboflow")
project = rf.workspace("first-qz6qj").project("train-model-izydu-dpmbj")
version = project.version(3)
dataset = version.download("yolov8")
yo = {"test":"/content/train-model-11/test/images",
        "train":"/content/train-model-11/train/images",
        "val":"/content/train-model-11/valid/images",
        "names":["-OgPv","Downy mildew","black-leaf","powdery mildew"],
        "nc":4}
yo = yaml.dump(yo)
with open("training.yaml","w+") as f:
  f.write(yo)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Detecting-diseases-1 in yolov8:: 100%|██████████| 22614/22614 [00:03<00:00, 6087.51it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# # **Import Libraries**

# %%
import yaml
import numpy as np
from ultralytics import YOLO
import cv2 as cv
import matplotlib.pyplot as plt

# %% [markdown]
# # **Create training file**

# %%
yo = {"test":"/content/train-model-11/test/images",
        "train":"/content/train-model-11/train/images",
        "val":"/content/train-model-11/valid/images",
        "names":["-OgPv","Downy mildew","black-leaf","powdery mildew"],
        "nc":4}
yo = yaml.dump(yo)
with open("training.yaml","w+") as f:
  f.write(yo)

# %% [markdown]
# # **Download model**

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 270MB/s]

# %% [markdown]
# # **First stadge**
# > Freeze Backbone(Transfer Learning)

# %%
! yolo mode=train model=yolov8m.pt task=detect data=training.yaml epochs=100 imgsz=640 batch=16 freeze=10
# Out:
# Ultralytics 8.3.73 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
version.deploy("yolov8","runs/detect/train","weights/best.pt")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.3.73, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/first-qz6qj/train-model-izydu-dpmbj/3
# Share your model with the world at: https://universe.roboflow.com/first-qz6qj/train-model-izydu-dpmbj/model/3

# %% [markdown]
# # **Second Stadge**
# > Retrain the best weights without freezing

# %%
! yolo mode=train task=detect data=training.yaml model=/content/runs/detect/train/weights/best.pt batch=16 imgsz=640 epochs=100
# Out:
# Ultralytics 8.3.73 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
version = project.version(4)
version.deploy("yolov8","runs/detect/train2","weights/best.pt")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.3.73, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/first-qz6qj/train-model-izydu-dpmbj/4
# Share your model with the world at: https://universe.roboflow.com/first-qz6qj/train-model-izydu-dpmbj/model/4

# %%
! zip -r transfer_learning.zip /content/runs/detect/train
! zip -r finetuning.zip /content/runs/detect/train2
# Out:
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 3%)
#   adding: content/runs/detect/train/PR_curve.png (deflated 15%)
#   adding: content/runs/detect/train/roboflow_deploy.zip (stored 0%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 6%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 3%)
#   adding: content/runs/detect/train/results.png (deflated 8%)
#   adding: content/runs/detect/train/events.out.tfevents.1738942468.4a3210e2ff25.2634.0 (deflated 89%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 29%)
#   adding: content/runs/detect/train/args.yaml (deflated 53%)
#   adding: content/runs/detect/train/val_batch2_pred.jpg (deflated 5%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 8%)
# ...
